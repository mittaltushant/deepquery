# %%
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import pandas as pd
import copy
from dbclass import TrainDB

n_epochs = 3
batch_size_train = 32
batch_size_test = 1000
learning_rate = 0.01
momentum = 0.5
log_interval = 60000/(10*batch_size_train)

random_seed = 1
torch.backends.cudnn.enabled = False
torch.manual_seed(random_seed)

train_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('drive/My Drive/mnist/MNIST_data/', train=True, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_train, shuffle=False)

test_loader = torch.utils.data.DataLoader(
  torchvision.datasets.MNIST('drive/My Drive/mnist/MNIST_data/', train=False, download=True,
                             transform=torchvision.transforms.Compose([
                               torchvision.transforms.ToTensor(),
                               torchvision.transforms.Normalize(
                                 (0.1307,), (0.3081,))
                             ])),
  batch_size=batch_size_test, shuffle=True)

examples = enumerate(test_loader)
batch_idx, (example_data, example_targets) = next(examples)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x)


network = Net()
optimizer = optim.SGD(network.parameters(), lr=learning_rate,
                      momentum=momentum)

#net1 = Net()
#net2 = Net()

net1 = copy.deepcopy(network)
net2 = copy.deepcopy(network)
net3 = copy.deepcopy(network) 


train_losses = []
train_counter = []
test_losses = []
test_counter = [i*len(train_loader.dataset) for i in range(n_epochs + 1)]

# %%
db = TrainDB(network,train_loader, torch.nn.functional.nll_loss,batchfreq=100)

# %%
def train(epoch):
  network.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    #if batch_idx%50==0:
    #    print(batch_idx)
    grad_vec = None
    prev_state = copy.deepcopy(network.state_dict())
    optimizer.zero_grad()
    output = network(data)
    loss = F.nll_loss(output, target)
    loss.backward(create_graph=True,retain_graph=True)
    #grads = []
    #print(target)
    #for param in network.parameters():
    #    grads.append(param.grad.view(-1))
    #grads = torch.autograd.grad(
    #            loss, network.parameters(), create_graph=True
    #        )
    #grad_vec = torch.cat([g.contiguous().view(-1) for g in grads])
    #print('Norm of grad')
    #if batch_idx <20:
    #    print(grad_vec)
    #print(torch.norm(grad_vec/32.0))
    #grad_vec = 0
    optimizer.step()
    db.step(epoch,batch_idx,prev_state,network,loss.item())
    #print(db.tdiffnorm)
    if batch_idx % log_interval == 0:
      print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
        epoch, batch_idx * len(data), len(train_loader.dataset),
        100. * batch_idx / len(train_loader), loss.item()))
      train_losses.append(loss.item())
      train_counter.append(
        (batch_idx*batch_size_train) + ((epoch-1)*len(train_loader.dataset)))
  return

def test():
  network.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
    for data, target in test_loader:
      output = network(data)
      test_loss += F.nll_loss(output, target, size_average=False).item()
      pred = output.data.max(1, keepdim=True)[1]
      correct += pred.eq(target.data.view_as(pred)).sum()
  test_loss /= len(test_loader.dataset)
  test_losses.append(test_loss)
  print('\nTest set: Avg. loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss, correct, len(test_loader.dataset),
    100. * correct / len(test_loader.dataset)))


test()
n_epochs = 1
for epoch in range(1, n_epochs + 1):
  train(epoch)
  test()
#db.finnetwork = network
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:59: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# /usr/local/lib/python3.7/site-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# Test set: Avg. loss: 2.3004, Accuracy: 751/10000 (7%)
#
# 0
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.329942
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# Train Epoch: 1 [12000/60000 (20%)]	Loss: 0.940901
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.660979
# 800
# 850
# 900
# 950
# 1000
# 1050
# 1100
# Train Epoch: 1 [36000/60000 (60%)]	Loss: 0.456088
# 1150
# 1200
# 1250
# 1300
# 1350
# 1400
# 1450
# 1500
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.302643
# 1550
# 1600
# 1650
# 1700
# 1750
# 1800
# 1850
#
# Test set: Avg. loss: 0.1419, Accuracy: 9570/10000 (95%)

# %%
table1 = db.tweight
table3 = db.tdiffnorm
table2 = db.tnorm

#table3[['conv1.weight', 'conv2.weight', 'fc1.weight', 'fc2.weight']][1:].plot()
#table2[['conv1.weight', 'conv2.weight', 'fc1.weight', 'fc2.weight']].plot()
table2
# Out:
#         conv1.weight  conv1.bias  conv2.weight  conv2.bias  fc1.weight  \
# 0 0         1.835035    0.347588      2.590909    0.170132    0.809592
# 1 0         1.834912    0.347498      2.590820    0.170012    0.809675
#   1         1.834888    0.347586      2.590842    0.170018    0.809717
#   2         1.834631    0.347548      2.590701    0.169730    0.809778
#   3         1.834439    0.347614      2.590631    0.169358    0.809835
# ...              ...         ...           ...         ...         ...
#   1870      2.755737    0.403736      3.623700    0.158214    1.759621
#   1871      2.756150    0.403682      3.624147    0.158209    1.759668
#   1872      2.755474    0.403915      3.623782    0.158215    1.757414
#   1873      2.755699    0.404117      3.624093    0.158215    1.756881
#   1874      2.756150    0.404292      3.624556    0.158281    1.756945
#
#         fc1.bias  fc2.weight  fc2.bias
# 0 0     0.221882    0.762469  0.220865
# 1 0     0.221834    0.762511  0.220336
#   1     0.221847    0.762801  0.220484
#   2     0.221797    0.762665  0.220352
#   3     0.221560    0.762522  0.219614
# ...          ...         ...       ...
#   1870  0.237817    1.539549  0.213421
#   1871  0.237836    1.539834  0.213266
#   1872  0.238025    1.538726  0.213238
#   1873  0.238196    1.539321  0.213293
#   1874  0.238226    1.538545  0.213470
#
# [1876 rows x 8 columns]

# %%
import cProfile
cProfile.run('db.ithhess_eigenval(k=4,opt=True)')
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:59: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
# [hessian_eigenthings] beginning deflated power iteration
# [hessian_eigenthings] computing eigenvalue/vector 1 of 4
#          4967601 function calls (4946640 primitive calls) in 250.561 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1875    0.147    0.000   17.863    0.010 <ipython-input-1-59cc902f2346>:52(forward)
#         1    0.002    0.002  250.556  250.556 <string>:1(<module>)
#    120000    0.150    0.000    0.207    0.000 Image.py:2329(_check_size)
#     60000    0.262    0.000    1.054    0.000 Image.py:2347(new)
#     60000    0.289    0.000    1.982    0.000 Image.py:2421(frombuffer)
#     60000    0.737    0.000    2.755    0.000 Image.py:2482(fromarray)
#     60000    0.305    0.000    0.428    0.000 Image.py:461(_getencoder)
#    180000    0.224    0.000    0.224    0.000 Image.py:539(__init__)
#    180000    0.041    0.000    0.041    0.000 Image.py:559(size)
#    120000    0.282    0.000    0.433    0.000 Image.py:563(_new)
#    180000    0.169    0.000    0.263    0.000 Image.py:613(__del__)
#     60000    0.370    0.000    1.692    0.000 Image.py:725(tobytes)
#     60000    0.076    0.000    0.106    0.000 Image.py:823(load)
#      3750    0.007    0.000    0.012    0.000 _VF.py:11(__getattr__)
#     60000    0.040    0.000    0.058    0.000 __init__.py:119(is_tensor)
#      3750    0.002    0.000    0.002    0.000 __init__.py:1404(_unwrap_optional)
#      3750    0.001    0.000    0.001    0.000 __init__.py:1472(annotate)
#      1876    0.020    0.000    0.040    0.000 __init__.py:20(_make_grads)
#      1875    0.023    0.000   22.741    0.012 __init__.py:38(backward)
#         1    0.003    0.003  194.867  194.867 __init__.py:93(grad)
#      1875    0.002    0.000    0.002    0.000 _collections_abc.py:302(__subclasshook__)
#      3750    0.016    0.000    3.452    0.001 _jit_internal.py:122(fn)
#      1875    0.002    0.000    0.002    0.000 _reduction.py:8(get_enum)
#     60000    0.033    0.000    0.060    0.000 _util.py:7(isStringType)
#      3750    0.002    0.000    0.021    0.000 abc.py:137(__instancecheck__)
#      1875    0.001    0.000    0.008    0.000 abc.py:141(__subclasscheck__)
#      3750    0.034    0.000   12.490    0.003 conv.py:317(forward)
#     227/1    0.001    0.000    0.003    0.003 copy.py:132(deepcopy)
#       143    0.000    0.000    0.000    0.000 copy.py:190(_deepcopy_atomic)
#        10    0.000    0.000    0.000    0.000 copy.py:219(_deepcopy_tuple)
#        10    0.000    0.000    0.000    0.000 copy.py:220(<listcomp>)
#       6/1    0.000    0.000    0.002    0.002 copy.py:236(_deepcopy_dict)
#        68    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#      54/1    0.000    0.000    0.002    0.002 copy.py:268(_reconstruct)
#        12    0.000    0.000    0.000    0.000 copy.py:273(<genexpr>)
#         6    0.000    0.000    0.000    0.000 copyreg.py:87(__newobj__)
# 5625/1875    0.050    0.000    0.287    0.000 dataloader.py:196(default_collate)
#      1875    0.009    0.000    0.230    0.000 dataloader.py:232(<listcomp>)
#         2    0.004    0.002    0.005    0.003 dataloader.py:518(__init__)
#      1876    0.086    0.000   14.685    0.008 dataloader.py:612(__next__)
#      1875    0.090    0.000   14.238    0.008 dataloader.py:615(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dataloader.py:715(__del__)
#         2    0.001    0.001    0.006    0.003 dataloader.py:818(__iter__)
#      1875    0.003    0.000    0.038    0.000 dataloader.py:821(__len__)
#         1    0.000    0.000    0.003    0.003 dbclass.py:225(reconstructnet)
#         1    0.138    0.138  250.554  250.554 dbclass.py:302(ithhess_eigenval)
#         1    0.000    0.000    0.000    0.000 dbclass.py:329(<listcomp>)
#      1875    0.009    0.000    0.481    0.000 dropout.py:100(forward)
#      1875    0.007    0.000    0.045    0.000 functional.py:1114(_get_softmax_dim)
#      1875    0.007    0.000    0.093    0.000 functional.py:1272(log_softmax)
#      3750    0.025    0.000    0.275    0.000 functional.py:1336(linear)
#      1875    0.013    0.000    0.057    0.000 functional.py:1735(nll_loss)
#     60000    1.547    0.000    3.322    0.000 functional.py:184(normalize)
#     60000    0.051    0.000    0.063    0.000 functional.py:23(_is_pil_image)
#     60000    0.095    0.000    0.173    0.000 functional.py:30(_is_tensor_image)
#     60000    1.273    0.000    5.881    0.000 functional.py:38(to_tensor)
#      3750    0.048    0.000    3.414    0.001 functional.py:404(max_pool2d_with_indices)
#      3750    0.020    0.000    3.435    0.001 functional.py:420(_max_pool2d)
#         1    0.001    0.001    0.003    0.003 functional.py:652(norm)
#      1875    0.016    0.000    0.178    0.000 functional.py:729(dropout)
#      1875    0.029    0.000    0.472    0.000 functional.py:767(dropout2d)
#      5625    0.014    0.000    0.454    0.000 functional.py:851(relu)
#         1    0.000    0.000    0.000    0.000 hvp_operator.py:135(zero_grad)
#         1    0.008    0.008  194.944  194.944 hvp_operator.py:144(compute_hessian_eigenthings)
#         1    0.004    0.004    0.014    0.014 hvp_operator.py:15(__init__)
#         9    0.002    0.000    0.004    0.000 hvp_operator.py:27(<genexpr>)
#         1    0.002    0.002  194.872  194.872 hvp_operator.py:46(apply)
#         1    0.002    0.002  194.869  194.869 hvp_operator.py:74(_apply_batch2)
#         1    0.000    0.000    0.000    0.000 hvp_operator.py:77(<listcomp>)
#         7    0.004    0.001    0.026    0.004 iostream.py:197(schedule)
#         5    0.000    0.000    0.000    0.000 iostream.py:309(_is_master_process)
#         5    0.001    0.000    0.014    0.003 iostream.py:322(_schedule_flush)
#         5    0.003    0.001    0.030    0.006 iostream.py:384(write)
#         7    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#      3750    0.027    0.000    0.309    0.000 linear.py:65(forward)
#         1    0.000    0.000    0.000    0.000 linecache.py:15(getline)
#         1    0.000    0.000    0.000    0.000 linecache.py:37(getlines)
#      1876    0.003    0.000    0.014    0.000 mnist.py:102(__len__)
#     60000    1.264    0.000   14.148    0.000 mnist.py:80(__getitem__)
#         1    0.000    0.000    0.001    0.001 module.py:1002(zero_grad)
# 11250/1875    0.162    0.000   17.895    0.010 module.py:483(__call__)
#         6    0.000    0.000    0.000    0.000 module.py:511(__setstate__)
#     24387    0.062    0.000    0.062    0.000 module.py:521(__getattr__)
#        45    0.006    0.000    0.011    0.000 module.py:771(_named_members)
#        45    0.002    0.000    0.016    0.000 module.py:784(parameters)
#        45    0.003    0.000    0.014    0.000 module.py:808(named_parameters)
#        30    0.002    0.000    0.002    0.000 module.py:829(<lambda>)
#     85/35    0.001    0.000    0.002    0.000 module.py:938(named_modules)
#         8    0.000    0.000    0.000    0.000 parameter.py:23(__new__)
#         8    0.000    0.000    0.001    0.000 parameter.py:28(__deepcopy__)
#         1    0.008    0.008  194.887  194.887 power_iter.py:102(power_iteration)
#         1    0.000    0.000    0.000    0.000 power_iter.py:16(__init__)
#         1    0.001    0.001  194.922  194.922 power_iter.py:41(deflated_power_iteration)
#      1876    0.051    0.000    0.070    0.000 sampler.py:158(__iter__)
#      1875    0.008    0.000    0.032    0.000 sampler.py:168(__len__)
#         1    0.000    0.000    0.000    0.000 sampler.py:33(__iter__)
#      1875    0.002    0.000    0.021    0.000 sampler.py:36(__len__)
#         7    0.020    0.003    0.020    0.003 socket.py:342(send)
#      1876    0.007    0.000    0.008    0.000 tensor.py:409(__len__)
#        80    0.000    0.000    0.000    0.000 tensor.py:430(__hash__)
#      1875    0.022    0.000   22.762    0.012 tensor.py:74(backward)
#         1    0.000    0.000    0.000    0.000 thnn.py:9(__deepcopy__)
#         7    0.000    0.000    0.000    0.000 threading.py:1038(_wait_for_tstate_lock)
#         7    0.002    0.000    0.002    0.000 threading.py:1080(is_alive)
#         7    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#     60000    0.222    0.000    3.544    0.000 transforms.py:155(__call__)
#     60000    0.247    0.000    9.836    0.000 transforms.py:58(__call__)
#     60000    0.164    0.000    6.045    0.000 transforms.py:83(__call__)
#      3750    0.017    0.000    0.035    0.000 typing.py:245(inner)
#      3750    0.013    0.000    0.018    0.000 typing.py:661(__hash__)
#         2    0.000    0.000    0.034    0.017 utils.py:11(log)
#         1    0.000    0.000    0.000    0.000 warnings.py:117(_formatwarnmsg)
#         1    0.000    0.000    0.000    0.000 warnings.py:20(_showwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:35(_formatwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:419(__init__)
#         1    0.000    0.000    0.000    0.000 warnings.py:96(_showwarnmsg)
#     60000    0.228    0.000    0.228    0.000 {built-in method PIL._imaging.fill}
#     60000    0.251    0.000    0.251    0.000 {built-in method PIL._imaging.map_buffer}
#     60000    0.051    0.000    0.051    0.000 {built-in method PIL._imaging.raw_encoder}
#         6    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1008db040}
#      3750    0.010    0.000    0.019    0.000 {built-in method _abc._abc_instancecheck}
#      1875    0.005    0.000    0.007    0.000 {built-in method _abc._abc_subclasscheck}
#         8    0.000    0.000    0.000    0.000 {built-in method _make_subclass}
#      1875    0.030    0.000    0.030    0.000 {built-in method _warnings.warn}
#      3750    0.211    0.000    0.211    0.000 {built-in method addmm}
#         1    0.005    0.005  250.561  250.561 {built-in method builtins.exec}
#     63867    0.063    0.000    0.063    0.000 {built-in method builtins.getattr}
#    360006    0.095    0.000    0.095    0.000 {built-in method builtins.hasattr}
#      3750    0.004    0.000    0.004    0.000 {built-in method builtins.hash}
#       463    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#    500688    0.199    0.000    0.220    0.000 {built-in method builtins.isinstance}
#        63    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       4/3    0.000    0.000    0.006    0.002 {built-in method builtins.iter}
# 446255/438754    0.106    0.000    0.130    0.000 {built-in method builtins.len}
#     60000    0.063    0.000    0.063    0.000 {built-in method builtins.max}
#      1876    0.004    0.000    0.075    0.000 {built-in method builtins.next}
#         2    0.003    0.002    0.033    0.017 {built-in method builtins.print}
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.sum}
#         1    0.011    0.011    0.011    0.011 {built-in method cat}
#      3750   12.449    0.003   12.449    0.003 {built-in method conv2d}
#      1875    0.157    0.000    0.157    0.000 {built-in method dropout}
#      1875    0.436    0.000    0.436    0.000 {built-in method feature_dropout}
#         1    0.001    0.001    0.001    0.001 {built-in method frobenius_norm}
#     60000    0.127    0.000    0.127    0.000 {built-in method from_buffer}
#      1875    0.014    0.000    0.014    0.000 {built-in method ones_like}
#         5    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method randn_like}
#         1    0.005    0.005    0.005    0.005 {built-in method rand}
#      5625    0.440    0.000    0.440    0.000 {built-in method relu}
#      1875    0.195    0.000    0.195    0.000 {built-in method stack}
#    120000    0.526    0.000    0.526    0.000 {built-in method tensor}
#     11250    0.041    0.000    0.041    0.000 {built-in method torch._C._get_tracing_state}
#      3750    3.330    0.001    3.330    0.001 {built-in method torch._C._nn.max_pool2d_with_indices}
#      1875    0.036    0.000    0.036    0.000 {built-in method torch._C._nn.nll_loss}
#        54    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         7    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#        70    0.001    0.000    0.001    0.000 {method 'add' of 'set' objects}
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    121951    0.029    0.000    0.029    0.000 {method 'append' of 'list' objects}
#     60008    0.302    0.000    0.302    0.000 {method 'clone' of 'torch._C._TensorBase' objects}
#     60008    0.021    0.000    0.021    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#    120000    0.025    0.000    0.025    0.000 {method 'copy' of 'dict' objects}
#      9377    0.005    0.000    0.005    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     60000    1.233    0.000    1.233    0.000 {method 'div' of 'torch._C._TensorBase' objects}
#     60000    0.314    0.000    0.314    0.000 {method 'div_' of 'torch._C._TensorBase' objects}
#     60000    0.624    0.000    0.624    0.000 {method 'encode' of 'ImagingEncoder' objects}
#     60000    0.522    0.000    0.522    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#      1887    0.008    0.000    0.008    0.000 {method 'format' of 'str' objects}
#     60503    0.018    0.000    0.018    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#        60    0.000    0.000    0.000    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#     60000    0.015    0.000    0.015    0.000 {method 'join' of 'bytes' objects}
#      1875    0.040    0.000    0.040    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#     60000    0.021    0.000    0.021    0.000 {method 'ndimension' of 'torch._C._TensorBase' objects}
#      1883    0.004    0.000    0.004    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#     60000    0.177    0.000    0.177    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#     60000    0.030    0.000    0.030    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#         2    0.002    0.001    0.002    0.001 {method 'random_' of 'torch._C._TensorBase' objects}
#      1876  217.540    0.116  217.540    0.116 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     60000    0.043    0.000    0.043    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#      3750    0.006    0.000    0.006    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#     60000    0.460    0.000    0.460    0.000 {method 'sub_' of 'torch._C._TensorBase' objects}
#      3750    0.036    0.000    0.036    0.000 {method 't' of 'torch._C._TensorBase' objects}
#    120000    0.430    0.000    0.430    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#     22500    0.011    0.000    0.011    0.000 {method 'values' of 'collections.OrderedDict' objects}
#     61883    0.427    0.000    0.427    0.000 {method 'view' of 'torch._C._TensorBase' objects}
#         8    0.000    0.000    0.000    0.000 {method 'zero_' of 'torch._C._TensorBase' objects}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c44bc1ba3aeb> in <module>
#       1 import cProfile
# ----> 2 cProfile.run('db.ithhess_eigenval(k=4,opt=True)')
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in run(statement, filename, sort)
#      14
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#      17
#      18 def runctx(statement, globals, locals, filename=None, sort=-1):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/profile.py in run(self, statement, filename, sort)
#      51         prof = self.profiler()
#      52         try:
# ---> 53             prof.run(statement)
#      54         except SystemExit:
#      55             pass
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in run(self, cmd)
#      93         import __main__
#      94         dict = __main__.__dict__
# ---> 95         return self.runctx(cmd, dict, dict)
#      96
#      97     def runctx(self, cmd, globals, locals):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/dbclass.py in ithhess_eigenval(self, epoch, batch_id, k, opt)
#     328
#     329             grad_vec = torch.cat([g.contiguous().view(-1) for g in grads])
# --> 330             eigenvals, eigenvecs = compute_hessian_eigenthings(network,self.dataloader,self.criterion,grad_vec,weird=self.weird,num_eigenthings=k,opt=True)
#     331             return (eigenvals, eigenvecs)
#     332
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in compute_hessian_eigenthings(model, dataloader, loss, grad_vec, weird, num_eigenthings, full_dataset, mode, use_gpu, max_samples, opt, **kwargs)
#     200     if mode == "power_iter":
#     201         eigenvals, eigenvecs = deflated_power_iteration(
# --> 202             hvp_operator, num_eigenthings, use_gpu=use_gpu, **kwargs
#     203         )
#     204     elif mode == "lanczos":
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in deflated_power_iteration(operator, num_eigenthings, power_iter_steps, power_iter_err_threshold, momentum, use_gpu, to_numpy)
#      74             momentum=momentum,
#      75             use_gpu=use_gpu,
# ---> 76             init_vec=prev_vec,
#      77         )
#      78         log("eigenvalue %d: %.4f" % (i + 1, eigenval))
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in power_iteration(operator, steps, error_threshold, momentum, use_gpu, init_vec)
#     124         prev_vec = vec / (torch.norm(vec) + 1e-6)
#     125         #t = time()
# --> 126         new_vec = operator.apply(vec) - momentum * prev_vec
#     127         #print("Step %d - Time taken = %d seconds"  %(i, time()-t) )
#     128         # need to handle case where we end up in the nullspace of the operator.
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in apply(self, vec)
#      50         """
#      51         if self.opt:
# ---> 52             return self._apply_batch2(vec)
#      53         else:
#      54
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in _apply_batch2(self, vec)
#      78         #print(torch.norm(self.grad_vec))
#      79         grad_grad = torch.autograd.grad(
# ---> 80             self.grad_vec, w, grad_outputs=vec, only_inputs=True,retain_graph=True
#      81             #, allow_unused=True
#      82         )
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     143     return Variable._execution_engine.run_backward(
#     144         outputs, grad_outputs, retain_graph, create_graph,
# --> 145         inputs, allow_unused)
#     146
#     147
#
# KeyboardInterrupt:

# %%
import cProfile
cProfile.run('db.ithhess_eigenval(k=4,opt=False)')
# Out:
# [hessian_eigenthings] beginning deflated power iteration
# [hessian_eigenthings] computing eigenvalue/vector 1 of 4
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:59: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#          8990621 function calls (8852256 primitive calls) in 135.632 seconds8m28s | Tot: 1ms | power iter error: 1.0000                                                              1/20
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2876    0.160    0.000   14.507    0.005 <ipython-input-1-59cc902f2346>:52(forward)
#         1    0.000    0.000  135.630  135.630 <string>:1(<module>)
#    184064    0.207    0.000    0.282    0.000 Image.py:2329(_check_size)
#     92032    0.332    0.000    1.416    0.000 Image.py:2347(new)
#     92032    0.393    0.000    2.651    0.000 Image.py:2421(frombuffer)
#     92032    0.898    0.000    3.599    0.000 Image.py:2482(fromarray)
#     92032    0.406    0.000    0.574    0.000 Image.py:461(_getencoder)
#    276096    0.294    0.000    0.294    0.000 Image.py:539(__init__)
#    276096    0.057    0.000    0.057    0.000 Image.py:559(size)
#    184064    0.380    0.000    0.584    0.000 Image.py:563(_new)
#    276096    0.237    0.000    0.370    0.000 Image.py:613(__del__)
#     92032    0.506    0.000    4.008    0.000 Image.py:725(tobytes)
#     92032    0.107    0.000    0.148    0.000 Image.py:823(load)
#      5752    0.009    0.000    0.015    0.000 _VF.py:11(__getattr__)
#     92032    0.054    0.000    0.076    0.000 __init__.py:119(is_tensor)
#      5752    0.002    0.000    0.002    0.000 __init__.py:1404(_unwrap_optional)
#      5752    0.002    0.000    0.002    0.000 __init__.py:1472(annotate)
#      5752    0.033    0.000    0.061    0.000 __init__.py:20(_make_grads)
#      5752    0.076    0.000   97.251    0.017 __init__.py:93(grad)
#      2876    0.003    0.000    0.003    0.000 _collections_abc.py:302(__subclasshook__)
#      5752    0.019    0.000    3.797    0.001 _jit_internal.py:122(fn)
#      2876    0.002    0.000    0.002    0.000 _reduction.py:8(get_enum)
#     92032    0.044    0.000    0.081    0.000 _util.py:7(isStringType)
#      5752    0.004    0.000    0.030    0.000 abc.py:137(__instancecheck__)
#      2876    0.002    0.000    0.012    0.000 abc.py:141(__subclasscheck__)
#      5752    0.042    0.000    8.949    0.002 conv.py:317(forward)
#     227/1    0.002    0.000    0.032    0.032 copy.py:132(deepcopy)
#       143    0.001    0.000    0.001    0.000 copy.py:190(_deepcopy_atomic)
#        10    0.000    0.000    0.000    0.000 copy.py:219(_deepcopy_tuple)
#        10    0.000    0.000    0.000    0.000 copy.py:220(<listcomp>)
#       6/1    0.001    0.000    0.020    0.020 copy.py:236(_deepcopy_dict)
#        68    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#      54/1    0.008    0.000    0.030    0.030 copy.py:268(_reconstruct)
#        12    0.000    0.000    0.002    0.000 copy.py:273(<genexpr>)
#         6    0.001    0.000    0.001    0.000 copyreg.py:87(__newobj__)
# 8628/2876    0.071    0.000    0.475    0.000 dataloader.py:196(default_collate)
#      2876    0.099    0.000    0.397    0.000 dataloader.py:232(<listcomp>)
#         2    0.003    0.001    0.003    0.001 dataloader.py:518(__init__)
#      2877    0.110    0.000   21.438    0.007 dataloader.py:612(__next__)
#      2876    0.115    0.000   20.770    0.007 dataloader.py:615(<listcomp>)
#         1    0.000    0.000    0.000    0.000 dataloader.py:715(__del__)
#         2    0.000    0.000    0.003    0.001 dataloader.py:818(__iter__)
#         2    0.000    0.000    0.003    0.002 dataloader.py:821(__len__)
#         1    0.000    0.000    0.036    0.036 dbclass.py:225(reconstructnet)
#         1    0.001    0.001  135.630  135.630 dbclass.py:302(ithhess_eigenval)
#      2876    0.010    0.000    0.313    0.000 dropout.py:100(forward)
#      2876    0.009    0.000    0.070    0.000 functional.py:1114(_get_softmax_dim)
#      2876    0.008    0.000    0.129    0.000 functional.py:1272(log_softmax)
#      5752    0.029    0.000    0.323    0.000 functional.py:1336(linear)
#      2876    0.015    0.000    0.066    0.000 functional.py:1735(nll_loss)
#     92032    2.104    0.000    4.486    0.000 functional.py:184(normalize)
#     92032    0.066    0.000    0.082    0.000 functional.py:23(_is_pil_image)
#     92032    0.123    0.000    0.228    0.000 functional.py:30(_is_tensor_image)
#     92032    1.732    0.000    9.549    0.000 functional.py:38(to_tensor)
#      5752    0.055    0.000    3.754    0.001 functional.py:404(max_pool2d_with_indices)
#      5752    0.022    0.000    3.776    0.001 functional.py:420(_max_pool2d)
#         3    0.000    0.000    0.000    0.000 functional.py:652(norm)
#      2876    0.018    0.000    0.206    0.000 functional.py:729(dropout)
#      2876    0.032    0.000    0.303    0.000 functional.py:767(dropout2d)
#      8628    0.014    0.000    0.324    0.000 functional.py:851(relu)
#      2876    0.026    0.000    0.161    0.000 hvp_operator.py:129(<listcomp>)
#      5752    0.056    0.000    0.513    0.000 hvp_operator.py:135(zero_grad)
#         1    0.000    0.000  135.593  135.593 hvp_operator.py:144(compute_hessian_eigenthings)
#         1    0.000    0.000    0.003    0.003 hvp_operator.py:15(__init__)
#         9    0.000    0.000    0.000    0.000 hvp_operator.py:27(<genexpr>)
#         2    0.000    0.000  135.559   67.779 hvp_operator.py:46(apply)
#      2876    0.139    0.000  135.321    0.047 hvp_operator.py:61(_apply_batch)
#      2875    0.026    0.000    0.131    0.000 hvp_operator.py:71(<listcomp>)
#         2    0.234    0.117  135.559   67.779 hvp_operator.py:88(_apply_full)
#      2876    0.662    0.000   59.680    0.021 hvp_operator.py:98(prepare_grad)
#       293    0.001    0.000    0.005    0.000 iostream.py:197(schedule)
#       288    0.000    0.000    0.000    0.000 iostream.py:309(_is_master_process)
#       288    0.000    0.000    0.000    0.000 iostream.py:322(_schedule_flush)
#         1    0.000    0.000    0.003    0.003 iostream.py:336(flush)
#       288    0.001    0.000    0.007    0.000 iostream.py:384(write)
#       293    0.000    0.000    0.000    0.000 iostream.py:93(_event_pipe)
#      5752    0.028    0.000    0.359    0.000 linear.py:65(forward)
#         1    0.000    0.000    0.002    0.002 linecache.py:15(getline)
#         1    0.002    0.002    0.002    0.002 linecache.py:37(getlines)
#         4    0.000    0.000    0.000    0.000 mnist.py:102(__len__)
#     92032    1.759    0.000   20.656    0.000 mnist.py:80(__getitem__)
#         1    0.000    0.000    0.004    0.004 module.py:1002(zero_grad)
# 17256/2876    0.175    0.000   14.548    0.005 module.py:483(__call__)
#         6    0.000    0.000    0.000    0.000 module.py:511(__setstate__)
#     37400    0.059    0.000    0.059    0.000 module.py:521(__getattr__)
#    103554    0.250    0.000    0.690    0.000 module.py:771(_named_members)
#    103554    0.060    0.000    0.811    0.000 module.py:784(parameters)
#    103554    0.061    0.000    0.751    0.000 module.py:808(named_parameters)
#     69036    0.046    0.000    0.060    0.000 module.py:829(<lambda>)
# 195602/80542    0.224    0.000    0.255    0.000 module.py:938(named_modules)
#         8    0.000    0.000    0.000    0.000 parameter.py:23(__new__)
#         8    0.001    0.000    0.008    0.001 parameter.py:28(__deepcopy__)
#         1    0.010    0.010  135.589  135.589 power_iter.py:102(power_iteration)
#         1    0.000    0.000    0.000    0.000 power_iter.py:16(__init__)
#         1    0.000    0.000  135.589  135.589 power_iter.py:41(deflated_power_iteration)
#      2877    0.057    0.000    0.081    0.000 sampler.py:158(__iter__)
#         2    0.000    0.000    0.003    0.002 sampler.py:168(__len__)
#         2    0.000    0.000    0.000    0.000 sampler.py:33(__iter__)
#         2    0.002    0.001    0.002    0.001 sampler.py:36(__len__)
#       293    0.004    0.000    0.004    0.000 socket.py:342(send)
#      2880    0.008    0.000    0.009    0.000 tensor.py:409(__len__)
#    184096    0.060    0.000    0.087    0.000 tensor.py:430(__hash__)
#         1    0.000    0.000    0.000    0.000 thnn.py:9(__deepcopy__)
#       294    0.000    0.000    0.000    0.000 threading.py:1038(_wait_for_tstate_lock)
#       294    0.000    0.000    0.001    0.000 threading.py:1080(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:216(__init__)
#         1    0.000    0.000    0.000    0.000 threading.py:240(__enter__)
#         1    0.000    0.000    0.000    0.000 threading.py:243(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:249(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:252(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:255(_is_owned)
#         1    0.000    0.000    0.002    0.002 threading.py:264(wait)
#         1    0.000    0.000    0.000    0.000 threading.py:499(__init__)
#       294    0.000    0.000    0.000    0.000 threading.py:507(is_set)
#         1    0.001    0.001    0.003    0.003 threading.py:534(wait)
#     92032    0.305    0.000    4.791    0.000 transforms.py:155(__call__)
#     92032    0.329    0.000   14.889    0.000 transforms.py:58(__call__)
#     92032    0.220    0.000    9.769    0.000 transforms.py:83(__call__)
#      5752    0.020    0.000    0.041    0.000 typing.py:245(inner)
#      5752    0.016    0.000    0.021    0.000 typing.py:661(__hash__)
#         2    0.000    0.000    0.000    0.000 utils.py:11(log)
#         2    0.001    0.001    0.001    0.001 utils.py:20(format_time)
#         1    0.004    0.004    0.014    0.014 utils.py:54(progress_bar)
#         1    0.000    0.000    0.002    0.002 warnings.py:117(_formatwarnmsg)
#         1    0.000    0.000    0.002    0.002 warnings.py:20(_showwarnmsg_impl)
#         1    0.000    0.000    0.002    0.002 warnings.py:35(_formatwarnmsg_impl)
#         1    0.000    0.000    0.000    0.000 warnings.py:419(__init__)
#         1    0.000    0.000    0.002    0.002 warnings.py:96(_showwarnmsg)
#     92032    0.317    0.000    0.317    0.000 {built-in method PIL._imaging.fill}
#     92032    0.315    0.000    0.315    0.000 {built-in method PIL._imaging.map_buffer}
#     92032    0.069    0.000    0.069    0.000 {built-in method PIL._imaging.raw_encoder}
#         6    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x1008db040}
#      5752    0.015    0.000    0.026    0.000 {built-in method _abc._abc_instancecheck}
#      2876    0.007    0.000    0.010    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _imp.lock_held}
#         8    0.000    0.000    0.000    0.000 {built-in method _make_subclass}
#         2    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#      2876    0.048    0.000    0.050    0.000 {built-in method _warnings.warn}
#      5752    0.248    0.000    0.248    0.000 {built-in method addmm}
#         1    0.002    0.002  135.632  135.632 {built-in method builtins.exec}
#     97901    0.090    0.000    0.091    0.000 {built-in method builtins.getattr}
#    552198    0.133    0.000    0.133    0.000 {built-in method builtins.hasattr}
#      5752    0.005    0.000    0.005    0.000 {built-in method builtins.hash}
#    184479    0.027    0.000    0.027    0.000 {built-in method builtins.id}
#    782614    0.271    0.000    0.301    0.000 {built-in method builtins.isinstance}
#        63    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       6/4    0.000    0.000    0.003    0.001 {built-in method builtins.iter}
# 673002/672992    0.126    0.000    0.137    0.000 {built-in method builtins.len}
#     94908    0.094    0.000    0.094    0.000 {built-in method builtins.max}
# 5754/2877    0.012    0.000   21.448    0.007 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#      5751    0.347    0.000    0.347    0.000 {built-in method cat}
#      5752    8.898    0.002    8.898    0.002 {built-in method conv2d}
#      2876    0.182    0.000    0.182    0.000 {built-in method dropout}
#      2876    0.261    0.000    0.261    0.000 {built-in method feature_dropout}
#         3    0.000    0.000    0.000    0.000 {built-in method frobenius_norm}
#     92032    0.164    0.000    0.164    0.000 {built-in method from_buffer}
#      2876    0.019    0.000    0.019    0.000 {built-in method ones_like}
#       288    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {built-in method randn_like}
#         1    0.001    0.001    0.001    0.001 {built-in method rand}
#      8628    0.310    0.000    0.310    0.000 {built-in method relu}
#      2876    0.262    0.000    0.262    0.000 {built-in method stack}
#         1    0.000    0.000    0.000    0.000 {built-in method sum}
#    184064    0.711    0.000    0.711    0.000 {built-in method tensor}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#     17256    0.045    0.000    0.045    0.000 {built-in method torch._C._get_tracing_state}
#      5752    3.656    0.001    3.656    0.001 {built-in method torch._C._nn.max_pool2d_with_indices}
#      2876    0.041    0.000    0.041    0.000 {built-in method torch._C._nn.nll_loss}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        54    0.003    0.000    0.003    0.000 {method '__reduce_ex__' of 'object' objects}
#       298    0.002    0.000    0.002    0.000 {method 'acquire' of '_thread.lock' objects}
#    161084    0.058    0.000    0.095    0.000 {method 'add' of 'set' objects}
#       294    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    189886    0.039    0.000    0.039    0.000 {method 'append' of 'list' objects}
#      5752    0.040    0.000    0.040    0.000 {method 'chunk' of 'torch._C._TensorBase' objects}
#     92040    0.401    0.000    0.401    0.000 {method 'clone' of 'torch._C._TensorBase' objects}
#    138040    0.046    0.000    0.046    0.000 {method 'contiguous' of 'torch._C._TensorBase' objects}
#    184064    0.036    0.000    0.036    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#     14387    0.005    0.000    0.005    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#     92032    1.550    0.000    1.550    0.000 {method 'div' of 'torch._C._TensorBase' objects}
#     92032    0.439    0.000    0.439    0.000 {method 'div_' of 'torch._C._TensorBase' objects}
#         1    0.004    0.004    0.004    0.004 {method 'dot' of 'torch._C._TensorBase' objects}
#     92032    2.547    0.000    2.547    0.000 {method 'encode' of 'ImagingEncoder' objects}
#     92032    0.717    0.000    0.717    0.000 {method 'float' of 'torch._C._TensorBase' objects}
#      2888    0.011    0.000    0.011    0.000 {method 'format' of 'str' objects}
#     92535    0.025    0.000    0.025    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#    138072    0.025    0.000    0.025    0.000 {method 'items' of 'collections.OrderedDict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#     92032    0.021    0.000    0.021    0.000 {method 'join' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#      2876    0.051    0.000    0.051    0.000 {method 'log_softmax' of 'torch._C._TensorBase' objects}
#     92032    0.029    0.000    0.029    0.000 {method 'ndimension' of 'torch._C._TensorBase' objects}
#      2884    0.004    0.000    0.004    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#     92032    0.247    0.000    0.247    0.000 {method 'numpy' of 'torch._C._TensorBase' objects}
#     92032    0.041    0.000    0.041    0.000 {method 'pixel_access' of 'ImagingCore' objects}
#         2    0.000    0.000    0.000    0.000 {method 'random_' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#      5752   96.756    0.017   96.756    0.017 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     92032    0.060    0.000    0.060    0.000 {method 'setimage' of 'ImagingEncoder' objects}
#      5752    0.007    0.000    0.007    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#     92032    0.610    0.000    0.610    0.000 {method 'sub_' of 'torch._C._TensorBase' objects}
#      5752    0.041    0.000    0.041    0.000 {method 't' of 'torch._C._TensorBase' objects}
#    184064    0.542    0.000    0.542    0.000 {method 'transpose' of 'torch._C._TensorBase' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#     34512    0.013    0.000    0.013    0.000 {method 'values' of 'collections.OrderedDict' objects}
#    140916    0.818    0.000    0.818    0.000 {method 'view' of 'torch._C._TensorBase' objects}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bb8febdef3a7> in <module>
#       1 import cProfile
# ----> 2 cProfile.run('db.ithhess_eigenval(k=4,opt=False)')
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in run(statement, filename, sort)
#      14
#      15 def run(statement, filename=None, sort=-1):
# ---> 16     return _pyprofile._Utils(Profile).run(statement, filename, sort)
#      17
#      18 def runctx(statement, globals, locals, filename=None, sort=-1):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/profile.py in run(self, statement, filename, sort)
#      51         prof = self.profiler()
#      52         try:
# ---> 53             prof.run(statement)
#      54         except SystemExit:
#      55             pass
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in run(self, cmd)
#      93         import __main__
#      94         dict = __main__.__dict__
# ---> 95         return self.runctx(cmd, dict, dict)
#      96
#      97     def runctx(self, cmd, globals, locals):
#
# /usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/cProfile.py in runctx(self, cmd, globals, locals)
#      98         self.enable()
#      99         try:
# --> 100             exec(cmd, globals, locals)
#     101         finally:
#     102             self.disable()
#
# <string> in <module>
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/dbclass.py in ithhess_eigenval(self, epoch, batch_id, k, opt)
#     332
#     333         else:
# --> 334             eigenvals, eigenvecs = compute_hessian_eigenthings(network,self.dataloader,self.criterion,None,weird=self.weird,num_eigenthings=k,opt=False)
#     335             return (eigenvals, eigenvecs)
#     336
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in compute_hessian_eigenthings(model, dataloader, loss, grad_vec, weird, num_eigenthings, full_dataset, mode, use_gpu, max_samples, opt, **kwargs)
#     200     if mode == "power_iter":
#     201         eigenvals, eigenvecs = deflated_power_iteration(
# --> 202             hvp_operator, num_eigenthings, use_gpu=use_gpu, **kwargs
#     203         )
#     204     elif mode == "lanczos":
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in deflated_power_iteration(operator, num_eigenthings, power_iter_steps, power_iter_err_threshold, momentum, use_gpu, to_numpy)
#      74             momentum=momentum,
#      75             use_gpu=use_gpu,
# ---> 76             init_vec=prev_vec,
#      77         )
#      78         log("eigenvalue %d: %.4f" % (i + 1, eigenval))
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in power_iteration(operator, steps, error_threshold, momentum, use_gpu, init_vec)
#     124         prev_vec = vec / (torch.norm(vec) + 1e-6)
#     125         #t = time()
# --> 126         new_vec = operator.apply(vec) - momentum * prev_vec
#     127         #print("Step %d - Time taken = %d seconds"  %(i, time()-t) )
#     128         # need to handle case where we end up in the nullspace of the operator.
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in apply(self, vec)
#      54
#      55             if self.full_dataset:
# ---> 56                 return self._apply_full(vec)
#      57             else:
#      58                 return self._apply_batch(vec)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in _apply_full(self, vec)
#      91         for _ in range(n):
#      92             if hessian_vec_prod is not None:
# ---> 93                 hessian_vec_prod += self._apply_batch(vec)
#      94             else:
#      95                 hessian_vec_prod = self._apply_batch(vec)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in _apply_batch(self, vec)
#      66         # take the second gradient
#      67         grad_grad = torch.autograd.grad(
# ---> 68             grad_vec, self.model.parameters(), grad_outputs=vec, only_inputs=True
#      69         )
#      70         # concatenate the results over the different components of the network
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     143     return Variable._execution_engine.run_backward(
#     144         outputs, grad_outputs, retain_graph, create_graph,
# --> 145         inputs, allow_unused)
#     146
#     147
#
# KeyboardInterrupt:

# %%
from power_iter import Operator, deflated_power_iteration, smallest_eigenvalue
from scipy.sparse.linalg import LinearOperator, eigsh
import scipy
def eigenvalue_analysis2(operator, k=1, tol=1e-6, max_iter=100, quiet=False):
    """Return largest EV in magnitude and smallest algebraic eigenvalue."""
    eigmax, eigmin = smallest_eigenvalue(operator.hvp_op,
                                       power_iter_steps=max_iter,
                                       power_iter_err_threshold=tol,
                                       momentum=0.0,
                                       device=operator.device, quiet=False)
    return eigmax, eigmin

# %%
eigmax, eigmin = eigenvalue_analysis2(hess2,max_iter=20)
