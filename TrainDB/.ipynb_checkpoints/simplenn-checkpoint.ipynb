# %% [markdown]
# # Handwritten Digit Recognition
# - Author = Amitrajit Bose
# - Dataset = MNIST
# - [Medium Article Link](https://medium.com/@amitrajit_bose/handwritten-digit-mnist-pytorch-977b5338e627)
# - Frameworks = PyTorch

# %% [markdown]
# ### Necessary Imports

# %%
# Import necessary packages
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt
from time import time
import numpy as np
import pandas as pd
import copy
from dbclass import TrainDB
from torchvision import datasets, transforms

# Define a transform to normalize the data
transform = transforms.Compose([transforms.ToTensor(),
                              transforms.Normalize((0.5,), (0.5,)),
                              ])

# Download and load the training data
trainset = datasets.MNIST('drive/My Drive/mnist/MNIST_data/', download=True, train=True, transform=transform)
valset = datasets.MNIST('drive/My Drive/mnist/MNIST_data/', download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
valloader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True)

# %% [markdown]
# ### Defining The Neural Network

# %%
from torch import nn

# Layer details for the neural network
input_size = 784
hidden_sizes = [128, 64]
output_size = 10

# Build a feed-forward network
model = nn.Sequential(nn.Linear(input_size, hidden_sizes[0]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[0], hidden_sizes[1]),
                      nn.ReLU(),
                      nn.Linear(hidden_sizes[1], output_size),
                      nn.LogSoftmax(dim=1))
criterion = nn.NLLLoss()

from torch import optim

# Optimizers require the parameters to optimize and a learning rate
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.5)
def f(X):
    if np.ndim(X) >1:
        return np.trace(X)
    else:
        return 0
def g(X):
    if np.ndim(X) >1:
        return np.trace(X)+10
    else:
        return 10
d = {'trace':f, 'trace2':g}

# %%
db = TrainDB(model,trainloader,criterion,dictf=d,dictg=d,batchfreq=100)

# %% [markdown]
# ### Core Training Of Neural Network

# %%
optimizer = optim.SGD(model.parameters(), lr=0.03, momentum=0.9)
time0 = time()
epochs = 2
for e in range(epochs):
    running_loss = 0
    for i, (images, labels) in enumerate(trainloader):
        prev_state = copy.deepcopy(model.state_dict())

        # Flatten MNIST images into a 784 long vector
        images = images.view(images.shape[0], -1)
    
        # Training pass
        optimizer.zero_grad()
        
        output = model(images)
        loss = criterion(output, labels)
        
        #This is where the model learns by backpropagating
        loss.backward(create_graph=True,retain_graph=True)
        #And optimizes its weights here
        optimizer.step()
        db.step(e,i,prev_state,model,loss.item())
        
        running_loss += loss.item()
    else:
        print("Epoch {} - Training loss: {}".format(e, running_loss/len(trainloader)))
       # print((model[0].weight))
print("\nTraining Time (in minutes) =",(time()-time0)/60)
# Out:
# Epoch 0 - Training loss: 0.35990693663229056
# Epoch 1 - Training loss: 0.16799336516939756
#
# Training Time (in minutes) = 0.4565428455670675

# %%
table1 = db.tweight
table2 = db.tnorm
table3 = db.tdiffnorm
table4 = db.tdictf


#table3[['0.weight', '2.weight', '4.weight']][:].plot()
#table2[['0.weight', '2.weight', '4.weight']].plot()
#table2.loc[1,'0.weight']
#table1.loc[1]
table4
# Out:
#         0.weight  0.bias   2.weight  2.bias   4.weight  4.bias
# count  39.000000    39.0  39.000000    39.0  39.000000    39.0
# mean    0.191355     0.0  -0.830966     0.0  -0.024677     0.0
# std     0.261565     0.0   0.342625     0.0   0.050115     0.0
# min    -0.401070     0.0  -1.364218     0.0  -0.102732     0.0
# 25%     0.022081     0.0  -1.137994     0.0  -0.064942     0.0
# 50%     0.294332     0.0  -0.838224     0.0  -0.031669     0.0
# 75%     0.398796     0.0  -0.592095     0.0   0.013392     0.0
# max     0.497412     0.0  -0.153049     0.0   0.070299     0.0

# %%
torch.from_numpy(table1.loc[(0,10),'0.weight'].values[0]).requires_grad

# %%
print((table1.memory_usage(True,True).sum())/1000000)
print((table2.memory_usage(True,True).sum())/1000)
print((table3.memory_usage(True,True).sum())/1000)

# %% [markdown]
# ### Model Evaluation

# %%
correct_count, all_count = 0, 0
for images,labels in valloader:
  for i in range(len(labels)):
    img = images[i].view(1, 784)
    # Turn off gradients to speed up this part
    with torch.no_grad():
        logps = model(img)

    # Output of the network are log-probabilities, need to take exponential for probabilities
    ps = torch.exp(logps)
    probab = list(ps.numpy()[0])
    pred_label = probab.index(max(probab))
    true_label = labels.numpy()[i]
    if(true_label == pred_label):
      correct_count += 1
    all_count += 1

print("Number Of Images Tested =", all_count)
print("\nModel Accuracy =", (correct_count/all_count))

# %%
print(db.currnetwork.state_dict()['0.weight'])
print(db.reconstructnet(None,None).state_dict()['0.weight'])

# %%
#db.criterion = torch.nn.functional.nll_loss
db.ithhess_eigenval(k=4)
# Out:
# [hessian_eigenthings] beginning deflated power iteration
# [hessian_eigenthings] computing eigenvalue/vector 1 of 4
# Step 0 - Time taken = 1 seconds
# Step 1 - Time taken = 1 seconds....................................]  Step: 55s274ms | Tot: 1ms | power iter error: 1.0000                                                           1/20
# Step 2 - Time taken = 1 seconds....................................]  Step: 1s487ms | Tot: 1s488ms | power iter error: 856.2453                                                      2/20
# Step 3 - Time taken = 1 seconds....................................]  Step: 1s488ms | Tot: 2s977ms | power iter error: 0.4090                                                        3/20
# Step 4 - Time taken = 1 seconds....................................]  Step: 1s476ms | Tot: 4s454ms | power iter error: 0.0808                                                        4/20
# Step 5 - Time taken = 1 seconds....................................]  Step: 1s483ms | Tot: 5s937ms | power iter error: 0.0303                                                        5/20
# Step 6 - Time taken = 1 seconds....................................]  Step: 1s755ms | Tot: 7s693ms | power iter error: 0.0111                                                        6/20
# Step 7 - Time taken = 1 seconds....................................]  Step: 1s470ms | Tot: 9s163ms | power iter error: 0.0040                                                        7/20
# Step 8 - Time taken = 1 seconds....................................]  Step: 1s480ms | Tot: 10s644ms | power iter error: 0.0014                                                       8/20
# Step 9 - Time taken = 1 seconds....................................]  Step: 1s466ms | Tot: 12s111ms | power iter error: 0.0005                                                       9/20
# Step 10 - Time taken = 1 seconds...................................]  Step: 1s616ms | Tot: 13s727ms | power iter error: 0.0002                                                       10/20
# [hessian_eigenthings] eigenvalue 1: 6.0350.........................]  Step: 1s497ms | Tot: 15s225ms | power iter error: 0.0001                                                       11/20
# [hessian_eigenthings] computing eigenvalue/vector 2 of 4
# Step 0 - Time taken = 1 seconds
# Step 1 - Time taken = 1 seconds....................................]  Step: 1s497ms | Tot: 1ms | power iter error: 1.0000                                                            1/20
# Step 2 - Time taken = 1 seconds....................................]  Step: 1s489ms | Tot: 1s490ms | power iter error: 1.0000                                                        2/20
# Step 3 - Time taken = 1 seconds....................................]  Step: 1s489ms | Tot: 2s980ms | power iter error: 0.0011                                                        3/20
# Step 4 - Time taken = 1 seconds....................................]  Step: 1s496ms | Tot: 4s476ms | power iter error: 0.0008                                                        4/20
# Step 5 - Time taken = 1 seconds....................................]  Step: 1s690ms | Tot: 6s166ms | power iter error: 0.0006                                                        5/20
# Step 6 - Time taken = 1 seconds....................................]  Step: 1s663ms | Tot: 7s830ms | power iter error: 0.0005                                                        6/20
# Step 7 - Time taken = 1 seconds....................................]  Step: 1s649ms | Tot: 9s480ms | power iter error: 0.0003                                                        7/20
# Step 8 - Time taken = 1 seconds....................................]  Step: 1s468ms | Tot: 10s948ms | power iter error: 0.0003                                                       8/20
# Step 9 - Time taken = 1 seconds....................................]  Step: 1s483ms | Tot: 12s431ms | power iter error: 0.0002                                                       9/20
# Step 10 - Time taken = 1 seconds...................................]  Step: 1s560ms | Tot: 13s992ms | power iter error: 0.0002                                                       10/20
# Step 11 - Time taken = 1 seconds==>................................]  Step: 1s987ms | Tot: 15s979ms | power iter error: 0.0001                                                       11/20
# [hessian_eigenthings] eigenvalue 2: 3.6562.........................]  Step: 1s992ms | Tot: 17s972ms | power iter error: 0.0001                                                       12/20
# [hessian_eigenthings] computing eigenvalue/vector 3 of 4
# Step 0 - Time taken = 2 seconds
# Step 1 - Time taken = 1 seconds....................................]  Step: 2s82ms | Tot: 0ms | power iter error: 1.0000                                                             1/20
#  [===>.............................................................]  Step: 1s806ms | Tot: 1s807ms | power iter error: 0.9999                                                        2/20
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e96c32fa6ea2> in <module>
#       1 #db.criterion = torch.nn.functional.nll_loss
# ----> 2 db.ithhess_eigenval(k=4)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/dbclass.py in ithhess_eigenval(self, epoch, batch_id, k)
#     272
#     273         grad_vec = torch.cat([g.contiguous().view(-1) for g in grads])
# --> 274         compute_hessian_eigenthings(network,grad_vec,num_eigenthings=k)
#     275
#     276         #hess = HessianOperator(network, grads)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in compute_hessian_eigenthings(model, grad_vec, num_eigenthings, full_dataset, mode, use_gpu, max_samples, **kwargs)
#     142     if mode == "power_iter":
#     143         eigenvals, eigenvecs = deflated_power_iteration(
# --> 144             hvp_operator, num_eigenthings, use_gpu=use_gpu, **kwargs
#     145         )
#     146     elif mode == "lanczos":
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in deflated_power_iteration(operator, num_eigenthings, power_iter_steps, power_iter_err_threshold, momentum, use_gpu, to_numpy)
#      72             momentum=momentum,
#      73             use_gpu=use_gpu,
# ---> 74             init_vec=prev_vec,
#      75         )
#      76         log("eigenvalue %d: %.4f" % (i + 1, eigenval))
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in power_iteration(operator, steps, error_threshold, momentum, use_gpu, init_vec)
#     122         prev_vec = vec / (torch.norm(vec) + 1e-6)
#     123         t = time()
# --> 124         new_vec = operator.apply(vec) - momentum * prev_vec
#     125         print("Step %d - Time taken = %d seconds"  %(i, time()-t) )
#     126         # need to handle case where we end up in the nullspace of the operator.
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in apply(self, x)
#      34
#      35     def apply(self, x):
# ---> 36         return self.apply_fn(x)
#      37
#      38
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in _new_op_fn(x, op, val, vec)
#      77
#      78         def _new_op_fn(x, op=current_op, val=eigenval, vec=eigenvec):
# ---> 79             return op.apply(x) - _deflate(x, val, vec)
#      80
#      81         current_op = LambdaOperator(_new_op_fn, operator.size)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in apply(self, x)
#      34
#      35     def apply(self, x):
# ---> 36         return self.apply_fn(x)
#      37
#      38
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py in _new_op_fn(x, op, val, vec)
#      77
#      78         def _new_op_fn(x, op=current_op, val=eigenval, vec=eigenvec):
# ---> 79             return op.apply(x) - _deflate(x, val, vec)
#      80
#      81         current_op = LambdaOperator(_new_op_fn, operator.size)
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in apply(self, vec)
#      42         the vectorized model parameters
#      43         """
# ---> 44         return self._apply_batch(vec)
#      45         '''
#      46         if self.full_dataset:
#
# ~/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/hvp_operator.py in _apply_batch(self, vec)
#      64         #print(torch.norm(self.grad_vec))
#      65         grad_grad = torch.autograd.grad(
# ---> 66             self.grad_vec, w, grad_outputs=vec, only_inputs=True,retain_graph=True
#      67             #, allow_unused=True
#      68         )
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused)
#     143     return Variable._execution_engine.run_backward(
#     144         outputs, grad_outputs, retain_graph, create_graph,
# --> 145         inputs, allow_unused)
#     146
#     147
#
# KeyboardInterrupt:

# %%
from hessian_eigenthings2.hvp_operator import compute_hessian_eigenthings

network = copy.deepcopy(db.currnetwork)
eigvec,eigenvalues = compute_hessian_eigenthings(network,trainloader, criterion,num_eigenthings=4, use_gpu=False,power_iter_steps=20)
# Out:
# [hessian_eigenthings] beginning deflated power iteration
# [hessian_eigenthings] computing eigenvalue/vector 1 of 4
# Step 0 - Time taken = 13 seconds
# Step 1 - Time taken = 12 seconds...................................]  Step: 20s188ms | Tot: 0ms | power iter error: 1.0000                                                           1/20
# Step 2 - Time taken = 25 seconds...................................]  Step: 12s448ms | Tot: 12s449ms | power iter error: 806.2057                                                    2/20
# Step 3 - Time taken = 18 seconds...................................]  Step: 25s57ms | Tot: 37s506ms | power iter error: 0.3925                                                       3/20
# Step 4 - Time taken = 13 seconds...................................]  Step: 18s669ms | Tot: 56s176ms | power iter error: 0.0679                                                      4/20
# Step 5 - Time taken = 15 seconds...................................]  Step: 13s574ms | Tot: 1m9s | power iter error: 0.0244                                                          5/20
# Step 6 - Time taken = 13 seconds...................................]  Step: 15s288ms | Tot: 1m25s | power iter error: 0.0083                                                         6/20
# Step 7 - Time taken = 13 seconds...................................]  Step: 13s369ms | Tot: 1m38s | power iter error: 0.0030                                                         7/20
# Step 8 - Time taken = 14 seconds...................................]  Step: 13s22ms | Tot: 1m51s | power iter error: 0.0024                                                          8/20
# Step 9 - Time taken = 15 seconds...................................]  Step: 14s236ms | Tot: 2m5s | power iter error: 0.0003                                                          9/20
# Step 10 - Time taken = 18 seconds..................................]  Step: 15s607ms | Tot: 2m21s | power iter error: 0.0003                                                         10/20
# [hessian_eigenthings] eigenvalue 1: 6.0344.........................]  Step: 18s394ms | Tot: 2m39s | power iter error: 0.0001                                                         11/20
# [hessian_eigenthings] computing eigenvalue/vector 2 of 4
# Step 0 - Time taken = 19 seconds
# Step 1 - Time taken = 16 seconds...................................]  Step: 19s193ms | Tot: 0ms | power iter error: 1.0000                                                           1/20
# Step 2 - Time taken = 13 seconds...................................]  Step: 16s641ms | Tot: 16s642ms | power iter error: 1.0001                                                      2/20
# Step 3 - Time taken = 13 seconds...................................]  Step: 13s563ms | Tot: 30s205ms | power iter error: 0.0525                                                      3/20
# Step 4 - Time taken = 12 seconds...................................]  Step: 13s10ms | Tot: 43s216ms | power iter error: 0.0028                                                       4/20
# Step 5 - Time taken = 12 seconds...................................]  Step: 12s463ms | Tot: 55s680ms | power iter error: 0.0018                                                      5/20
# Step 6 - Time taken = 12 seconds...................................]  Step: 12s313ms | Tot: 1m7s | power iter error: 0.0005                                                          6/20
# Step 7 - Time taken = 12 seconds...................................]  Step: 12s386ms | Tot: 1m20s | power iter error: 0.0005                                                         7/20
# Step 8 - Time taken = 12 seconds...................................]  Step: 12s458ms | Tot: 1m32s | power iter error: 0.0002                                                         8/20
# Step 9 - Time taken = 13 seconds...................................]  Step: 12s485ms | Tot: 1m45s | power iter error: 0.0007                                                         9/20
# Step 10 - Time taken = 12 seconds..................................]  Step: 13s962ms | Tot: 1m59s | power iter error: 0.0005                                                         10/20
# Step 11 - Time taken = 12 seconds=>................................]  Step: 12s374ms | Tot: 2m11s | power iter error: 0.0009                                                         11/20
# Step 12 - Time taken = 14 seconds====>.............................]  Step: 12s414ms | Tot: 2m24s | power iter error: 0.0005                                                         12/20
# Step 13 - Time taken = 12 seconds========>.........................]  Step: 14s239ms | Tot: 2m38s | power iter error: 0.0001                                                         13/20
# Step 14 - Time taken = 12 seconds===========>......................]  Step: 12s409ms | Tot: 2m50s | power iter error: 0.0006                                                         14/20
# Step 15 - Time taken = 12 seconds==============>...................]  Step: 12s376ms | Tot: 3m3s | power iter error: 0.0007                                                          15/20
# Step 16 - Time taken = 12 seconds=================>................]  Step: 12s243ms | Tot: 3m15s | power iter error: 0.0004                                                         16/20
# Step 17 - Time taken = 12 seconds=====================>............]  Step: 12s212ms | Tot: 3m27s | power iter error: 0.0003                                                         17/20
# Step 18 - Time taken = 12 seconds========================>.........]  Step: 12s519ms | Tot: 3m40s | power iter error: 0.0004                                                         18/20
# Step 19 - Time taken = 15 seconds===========================>......]  Step: 12s603ms | Tot: 3m52s | power iter error: 0.0006                                                         19/20
#  [=============================================================>...]  Step: 15s914ms | Tot: 4m8s | power iter error: 0.0002                                                          20/20
# [hessian_eigenthings] eigenvalue 2: 3.6589
# [hessian_eigenthings] computing eigenvalue/vector 3 of 4
# Step 0 - Time taken = 12 seconds
# Step 1 - Time taken = 12 seconds...................................]  Step: 12s532ms | Tot: 0ms | power iter error: 1.0000                                                           1/20
# Step 2 - Time taken = 12 seconds...................................]  Step: 12s305ms | Tot: 12s305ms | power iter error: 1.0009                                                      2/20
# Step 3 - Time taken = 12 seconds...................................]  Step: 12s269ms | Tot: 24s575ms | power iter error: 0.2353                                                      3/20
# Step 4 - Time taken = 12 seconds...................................]  Step: 12s793ms | Tot: 37s368ms | power iter error: 0.0069                                                      4/20
# Step 5 - Time taken = 12 seconds...................................]  Step: 12s264ms | Tot: 49s632ms | power iter error: 0.0024                                                      5/20
# [hessian_eigenthings] eigenvalue 3: 3.2060.........................]  Step: 12s258ms | Tot: 1m1s | power iter error: 0.0000                                                          6/20
# [hessian_eigenthings] computing eigenvalue/vector 4 of 4
# Step 0 - Time taken = 12 seconds
# Step 1 - Time taken = 12 seconds...................................]  Step: 12s193ms | Tot: 0ms | power iter error: 1.0000                                                           1/20
# Step 2 - Time taken = 15 seconds...................................]  Step: 12s880ms | Tot: 12s881ms | power iter error: 0.9988                                                      2/20
#  [======>..........................................................]  Step: 15s405ms | Tot: 28s286ms | power iter error: 0.0153                                                      3/20
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-86f84fa42465>", line 4, in <module>
#     eigvec,eigenvalues = compute_hessian_eigenthings(network,trainloader, criterion,num_eigenthings=4, use_gpu=False,power_iter_steps=20)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings2/hvp_operator.py", line 174, in compute_hessian_eigenthings
#     hvp_operator, num_eigenthings, use_gpu=use_gpu, **kwargs
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 74, in deflated_power_iteration
#     init_vec=prev_vec,
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 124, in power_iteration
#     new_vec = operator.apply(vec) - momentum * prev_vec
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 36, in apply
#     return self.apply_fn(x)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 79, in _new_op_fn
#     return op.apply(x) - _deflate(x, val, vec)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 36, in apply
#     return self.apply_fn(x)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 79, in _new_op_fn
#     return op.apply(x) - _deflate(x, val, vec)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 36, in apply
#     return self.apply_fn(x)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings/power_iter.py", line 79, in _new_op_fn
#     return op.apply(x) - _deflate(x, val, vec)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings2/hvp_operator.py", line 49, in apply
#     return self._apply_full(vec)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings2/hvp_operator.py", line 71, in _apply_full
#     hessian_vec_prod += self._apply_batch(vec)
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings2/hvp_operator.py", line 56, in _apply_batch
#     grad_vec = self.prepare_grad()
#   File "/Users/tushant/Documents/Uchicago/Database/Project/deepquery/TrainDB/hessian_eigenthings2/hvp_operator.py", line 91, in prepare_grad
#     all_inputs, all_targets = next(self.dataloader_iter)
#   File "/usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 615, in __next__
#     batch = self.collate_fn([self.dataset[i] for i in indices])
#   File "/usr/local/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 615, in <listcomp>
#     batch = self.collate_fn([self.dataset[i] for i in indices])
#   File "/usr/local/lib/python3.7/site-packages/torchvision/datasets/mnist.py", line 95, in __getitem__
#     img = self.transform(img)
#   File "/usr/local/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 60, in __call__
#     img = t(img)
#   File "/usr/local/lib/python3.7/site-packages/torchvision/transforms/transforms.py", line 163, in __call__
#     return F.normalize(tensor, self.mean, self.std, self.inplace)
#   File "/usr/local/lib/python3.7/site-packages/torchvision/transforms/functional.py", line 206, in normalize
#     mean = torch.tensor(mean, dtype=torch.float32)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2040, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 319, in wrapped
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.7/site-packages/IPython/core/ultratb.py", line 353, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/usr/local/Cellar/python/3.7.2_2/Frameworks/Python.framework/Versions/3.7/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
